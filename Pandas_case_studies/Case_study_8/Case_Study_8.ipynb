# %%
import numpy as np
import pandas as pd

# %%
interest_map = pd.read_csv(r"C:\Users\THINKPAD\Desktop\PANDAS_CASE_STUDY\Case_study_8\interest_map.csv",index_col = 0)
interest_metrics = pd.read_csv(r"C:\Users\THINKPAD\Desktop\PANDAS_CASE_STUDY\Case_study_8\interest_metrics.csv",index_col = 0)
percentage_ranking = pd.read_csv(r"C:\Users\THINKPAD\Desktop\PANDAS_CASE_STUDY\Case_study_8\percentage_ranking.csv",index_col = 0)

# %%
interest_map
# Out:
#          id                interest_name  \
# 0         1          Fitness Enthusiasts
# 1         2                       Gamers
# 2         3              Car Enthusiasts
# 3         4    Luxury Retail Researchers
# 4         5    Brides & Wedding Planners
# ...     ...                          ...
# 1204  49979        Cape Cod News Readers
# 1205  50860  Food Delivery Service Users
# 1206  51119    Skin Disorder Researchers
# 1207  51120      Foot Health Researchers
# 1208  51678                     Plumbers
#
#                                        interest_summary           created_at  \
# 0     Consumers using fitness tracking apps and webs...  2016-05-26 14:57:59
# 1     Consumers researching game reviews and cheat c...  2016-05-26 14:57:59
# 2           Readers of automotive news and car reviews.  2016-05-26 14:57:59
# 3     Consumers researching luxury product reviews a...  2016-05-26 14:57:59
# 4         People researching wedding ideas and vendors.  2016-05-26 14:57:59
# ...

# %%
interest_map.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1209 entries, 0 to 1208
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1209 non-null   int64
#  1   interest_name     1209 non-null   object
#  2   interest_summary  1189 non-null   object
#  3   created_at        1209 non-null   object
#  4   last_modified     1209 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 56.7+ KB

# %%
interest_map['created_at'] = interest_map['created_at'].apply(pd.to_datetime)

# %%
interest_map['last_modified'] = interest_map['last_modified'].apply(pd.to_datetime)

# %%
interest_map.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1209 entries, 0 to 1208
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1209 non-null   int64
#  1   interest_name     1209 non-null   object
#  2   interest_summary  1189 non-null   object
#  3   created_at        1209 non-null   datetime64[ns]
#  4   last_modified     1209 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(2)
# memory usage: 56.7+ KB

# %%
interest_metrics
# Out:
#        _month   _year month_year  interest_id  composition  index_value  \
# 0         7.0  2018.0    07-2018      32486.0        11.89         6.19
# 1         7.0  2018.0    07-2018       6106.0         9.93         5.31
# 2         7.0  2018.0    07-2018      18923.0        10.85         5.29
# 3         7.0  2018.0    07-2018       6344.0        10.32         5.10
# 4         7.0  2018.0    07-2018        100.0        10.77         5.04
# ...       ...     ...        ...          ...          ...          ...
# 14268     NaN     NaN        NaN          NaN         1.62         0.71
# 14269     NaN     NaN        NaN          NaN         1.62         0.68
# 14270     NaN     NaN        NaN      21246.0         1.61         0.68
# 14271     NaN     NaN        NaN          NaN         1.51         0.63
# 14272     NaN     NaN        NaN          NaN         1.64         0.62
#
#        ranking  percentile_ranking
# 0            1               99.86
# ...

# %%
interest_metrics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14273 entries, 0 to 14272
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   _month              13079 non-null  float64
#  1   _year               13079 non-null  float64
#  2   month_year          13079 non-null  object
#  3   interest_id         13080 non-null  float64
#  4   composition         14273 non-null  float64
#  5   index_value         14273 non-null  float64
#  6   ranking             14273 non-null  int64
#  7   percentile_ranking  14273 non-null  float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 1003.6+ KB

# %%
percentage_ranking
# Out:
#    month  year month_year  a.attribute_interest_id  average_composition  \
# 0      7  2018    07-2018                    32486                11.89
# 1      7  2018    07-2018                    32486                11.89
# 2      7  2018    07-2018                     6106                 9.93
# 3      7  2018    07-2018                    18923                10.85
#
#    average_index  rank  percentile_rank
# 0           6.19     1            99.86
# 1           6.19     1            99.86
# 2           5.31     2            99.73
# 3           5.29     3            99.59

# %%
percentage_ranking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 0 to 3
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   month                    4 non-null      int64
#  1   year                     4 non-null      int64
#  2   month_year               4 non-null      object
#  3   a.attribute_interest_id  4 non-null      int64
#  4   average_composition      4 non-null      float64
#  5   average_index            4 non-null      float64
#  6   rank                     4 non-null      int64
#  7   percentile_rank          4 non-null      float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 288.0+ bytes

# %% [markdown]
# # Data Exploration and Cleaning

# %% [markdown]
# ## 1.Update the fresh_segments.interest_metrics table by modifying the month_year column to be a date data type with the start of the month
